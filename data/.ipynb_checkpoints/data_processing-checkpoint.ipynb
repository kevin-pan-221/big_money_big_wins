# %%
import pandas as pd

# %%
df = pd.read_excel('/Users/kevinpan/Downloads/all-leaguetables.xlsx')
# Out:
# /opt/homebrew/lib/python3.11/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
path7 = '/Users/kevinpan/Downloads/2021-2022.csv'
path8 = '/Users/kevinpan/Downloads/2022-2023.csv'

# %%
df2 = pd.read_csv(path7)

# %%
df
# Out:
#                   League   Season Position                    Team  Matches  \
# 0         Premier League  2015/16       2                  Arsenal       38
# 1         Premier League  2015/16      20              Aston Villa       38
# 2         Premier League  2015/16      16              Bournemouth       38
# 3         Premier League  2015/16      10                  Chelsea       38
# 4         Premier League  2015/16      15           Crystal Palace       38
# ..                   ...      ...      ...                     ...      ...
# 394  Major League Soccer     2019       15    San Jose Earthquakes       34
# 395  Major League Soccer     2019        4     Seattle Sounders FC       34
# 396  Major League Soccer     2019       21    Sporting Kansas City       34
# 397  Major League Soccer     2019        9              Toronto FC       34
# 398  Major League Soccer     2019       23  Vancouver Whitecaps FC       34
#
# ...

# %%
df["League"].unique()
# Out:
# array(['Premier League', 'La Liga', 'Bundesliga', 'Major League Soccer'],
#       dtype=object)

# %%
df["Team"].unique()
# Out:
# array(['Arsenal', 'Aston Villa', 'Bournemouth', 'Chelsea',
#        'Crystal Palace', 'Everton', 'Leicester City', 'Liverpool',
#        'Manchester City', 'Manchester United', 'Newcastle United',
#        'Norwich City', 'Southampton', 'Stoke City', 'Sunderland',
#        'Swansea City', 'Tottenham Hotspur', 'Watford',
#        'West Bromwich Albion', 'West Ham United', 'Burnley', 'Hull City',
#        'Middlesbrough', 'Brighton', 'Huddersfield Town', 'Cardiff City',
#        'Fulham', 'Wolverhampton Wanderers', 'Sheffield United',
#        'Athletic Bilbao', 'Atletico Madrid', 'Celta Vigo',
#        'Deportivo La Coruna', 'FC Barcelona', 'Getafe CF', 'Granada CF',
#        'Levante UD', 'Malaga CF', 'Rayo Vallecano', 'Espanyol',
#        'Real Betis Balompie', 'Real Madrid', 'Real Sociedad', 'SD Eibar',
#        'Sevilla FC', 'Sporting Gijon', 'UD Las Palmas', 'Valencia CF',
#        'Villarreal CF', 'CA Osasuna', 'CD Leganes', 'Deportivo Alaves',
# ...
