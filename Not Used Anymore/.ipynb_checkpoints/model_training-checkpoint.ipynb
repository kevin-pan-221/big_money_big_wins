# %%
import pandas as pd
import numpy as np

# %%
#Reading in Data

#Serie A
#Euros
serie_a_2020_2021 = pd.read_excel('Soccer Data/Serie A (done)/Serie A Stats - 2020-2023.xlsx', sheet_name = '2020-2021')
serie_a_2021_2022 = pd.read_excel('Soccer Data/Serie A (done)/Serie A Stats - 2020-2023.xlsx', sheet_name = '2021-2022')
serie_a_2022_2023 = pd.read_excel('Soccer Data/Serie A (done)/Serie A Stats - 2020-2023.xlsx', sheet_name = '2022-2023')
combined_serie_a_2020_2023 = pd.concat([serie_a_2020_2021, serie_a_2021_2022, serie_a_2022_2023], ignore_index=True)

#Saudi Arabia
#USD
saudi_arabia_2023_2024 = pd.read_excel('Soccer Data/Saudi Arabia (done)/Saudi Arabia Stats 2023-2024.xlsx', sheet_name = '2023-2024')

#Premier League
#Pounds
prem_2020_2021 = pd.read_excel('Soccer Data/Premier League (done)/Premier League Stats - 2020-2023.xlsx', sheet_name = '2020 - 2021')
prem_2021_2022 = pd.read_excel('Soccer Data/Premier League (done)/Premier League Stats - 2020-2023.xlsx', sheet_name = '2021 - 2022')
prem_2022_2023 = pd.read_excel('Soccer Data/Premier League (done)/Premier League Stats - 2020-2023.xlsx', sheet_name = '2022-2023')
combined_prem_2020_2023 = pd.concat([prem_2020_2021, prem_2021_2022, prem_2022_2023], ignore_index=True)

#MLS
#USD
mls_2020 = pd.read_excel('Soccer Data/MLS (done)/MLS Stats - 2020 - 2024 (USD)_.xlsx', sheet_name = '2020')
mls_2021 = pd.read_excel('Soccer Data/MLS (done)/MLS Stats - 2020 - 2024 (USD)_.xlsx', sheet_name = '2021')
mls_2022 = pd.read_excel('Soccer Data/MLS (done)/MLS Stats - 2020 - 2024 (USD)_.xlsx', sheet_name = '2022')
mls_2023 = pd.read_excel('Soccer Data/MLS (done)/MLS Stats - 2020 - 2024 (USD)_.xlsx', sheet_name = '2023')
mls_2024 = pd.read_excel('Soccer Data/MLS (done)/MLS Stats - 2020 - 2024 (USD)_.xlsx', sheet_name = '2024')
combined_mls_2020_2024 = pd.concat([mls_2020, mls_2021, mls_2022, mls_2023, mls_2024], ignore_index=True)

#Ligue 1
#Euros
ligue_2020_2021 = pd.read_excel('Soccer Data/Ligue 1 (done)/Ligue 1 Stats - 2020-2023.xlsx', sheet_name = '2020-2021')
ligue_2021_2022 = pd.read_excel('Soccer Data/Ligue 1 (done)/Ligue 1 Stats - 2020-2023.xlsx', sheet_name = '2021-2022')
ligue_2022_2023 = pd.read_excel('Soccer Data/Ligue 1 (done)/Ligue 1 Stats - 2020-2023.xlsx', sheet_name = '2022-2023')
combined_ligue_2020_2023 = pd.concat([ligue_2020_2021, ligue_2021_2022, ligue_2022_2023], ignore_index=True)

#La Liga
#Euros
liga_2020_2021 = pd.read_excel('Soccer Data/La Liga (done)/La Liga Stats 2020 - 2023.xlsx', sheet_name = '2020-2021')
liga_2021_2022 = pd.read_excel('Soccer Data/La Liga (done)/La Liga Stats 2020 - 2023.xlsx', sheet_name = '2021-2022')
liga_2022_2023 = pd.read_excel('Soccer Data/La Liga (done)/La Liga Stats 2020 - 2023.xlsx', sheet_name = '2022-2023')
combined_liga_2020_2023 = pd.concat([liga_2020_2021, liga_2021_2022, liga_2022_2023], ignore_index=True)

#Bundesliga
#Euros
bundes_2020_2021 = pd.read_excel('Soccer Data/Bundesliga (done)/Bundesliga Stats 2020 -2023.xlsx', sheet_name = '2020 - 2021')
bundes_2021_2022 = pd.read_excel('Soccer Data/Bundesliga (done)/Bundesliga Stats 2020 -2023.xlsx', sheet_name = '2021 - 2022')
bundes_2022_2023 = pd.read_excel('Soccer Data/Bundesliga (done)/Bundesliga Stats 2020 -2023.xlsx', sheet_name = '2022 - 2023')
combined_bundes_2020_2023 = pd.concat([bundes_2020_2021, bundes_2021_2022, bundes_2022_2023], ignore_index=True)

#Brazilian Serie A
#USD
brazil_2021 = pd.read_excel('Soccer Data/Brazilian Serie A (done)/Brazilian Serie A Stats - 2021 - 2023.xlsx', sheet_name = '2021')
brazil_2022 = pd.read_excel('Soccer Data/Brazilian Serie A (done)/Brazilian Serie A Stats - 2021 - 2023.xlsx', sheet_name = '2022')
brazil_2023 = pd.read_excel('Soccer Data/Brazilian Serie A (done)/Brazilian Serie A Stats - 2021 - 2023.xlsx', sheet_name = '2023')
combined_brazil_2021_2023 = pd.concat([brazil_2021, brazil_2022, brazil_2023], ignore_index=True)

#Chinese Super League
#USD 
csl_2019 = pd.read_excel('Chinese Super League Stats - 2019.xlsx')

# %%
all_league_data = pd.concat([combined_bundes_2020_2023, combined_liga_2020_2023, combined_ligue_2020_2023, combined_mls_2020_2024, combined_serie_a_2020_2023], ignore_index=True)

# %%
all_league_data
# Out:
#      Reg_Rank                 Club  MP   W   D   L  GF  GA    GD   Pts  ...  \
# 0          15              Arminia  34   9   8  17  26  52 -26.0  35.0  ...
# 1          13             Augsburg  34  10   6  18  36  54 -18.0  36.0  ...
# 2           1               Bayern  34  24   6   4  99  44  55.0  78.0  ...
# 3           3             Dortmund  34  20   4  10  75  46  29.0  64.0  ...
# 4           5  Eintracht Frankfurt  34  16  12   6  69  53  16.0  60.0  ...
# ..        ...                  ...  ..  ..  ..  ..  ..  ..   ...   ...  ...
# 386        16                Lecce  38   8  12  18  33  46 -13.0  36.0  ...
# 387        17               Verona  38   7  10  21  31  59 -28.0  31.0  ...
# 388        18               Spezia  38   6  13  19  31  62 -31.0  31.0  ...
# 389        19            Cremonese  38   5  12  21  36  69 -33.0  27.0  ...
# 390        20            Sampdoria  38   3  10  25  24  71 -47.0  19.0  ...
#
#      G+A-PK  xG.1  xAG.1  xG+xAG  npxG.1  npxG+xAG.1  Playoff_Rank   P  +/-  \
# 0      1.12  0.97   0.70    1.67    0.92        1.62           NaN NaN  NaN
# 1      1.65  1.10   0.76    1.86    0.98        1.74           NaN NaN  NaN
# 2      4.82  2.23   1.62    3.86    2.00        3.63           NaN NaN  NaN
# 3      3.76  1.95   1.50    3.45    1.78        3.28           NaN NaN  NaN
# 4      3.15  1.72   1.29    3.01    1.54        2.83           NaN NaN  NaN
# ..      ...   ...    ...     ...     ...         ...           ...  ..  ...
# 386    1.76  1.36   0.95    2.31    1.16        2.11           NaN NaN  NaN
# 387    1.13  1.09   0.77    1.86    1.01        1.78           NaN NaN  NaN
# 388    1.92  1.10   0.92    2.02    1.06        1.98           NaN NaN  NaN
# 389    2.26  1.24   0.99    2.23    1.20        2.19           NaN NaN  NaN
# 390    1.32  0.94   0.74    1.68    0.92        1.66           NaN NaN  NaN
#
#      PTS
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# ..   ...
# 386  NaN
# 387  NaN
# 388  NaN
# 389  NaN
# 390  NaN
#
# [391 rows x 49 columns]

# %%
all_league_data.columns
# Out:
# Index(['Reg_Rank', 'Club', 'MP', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts',
#        'Total Annual Payroll (Millions)', 'Average Annual Payroll (Millions)',
#        'Total Annual Payroll', 'Average Annual Payroll', '# Pl', 'Age', 'Poss',
#        'MP.1', 'Starts', 'Min', '90s', 'Gls', 'Ast', 'G+A', 'G-PK', 'PK',
#        'PKatt', 'CrdY', 'CrdR', 'xG', 'npxG', 'xAG', 'npxG+xAG', 'PrgC',
#        'PrgP', 'Gls.1', 'Ast.1', 'G+A.1', 'G-PK.1', 'G+A-PK', 'xG.1', 'xAG.1',
#        'xG+xAG', 'npxG.1', 'npxG+xAG.1', 'Playoff_Rank', 'P', '+/-', 'PTS'],
#       dtype='object')

# %%
all_league_data
# Out:
#      Reg_Rank                 Club  MP   W   D   L  GF  GA    GD   Pts  ...  \
# 0          15              Arminia  34   9   8  17  26  52 -26.0  35.0  ...
# 1          13             Augsburg  34  10   6  18  36  54 -18.0  36.0  ...
# 2           1               Bayern  34  24   6   4  99  44  55.0  78.0  ...
# 3           3             Dortmund  34  20   4  10  75  46  29.0  64.0  ...
# 4           5  Eintracht Frankfurt  34  16  12   6  69  53  16.0  60.0  ...
# ..        ...                  ...  ..  ..  ..  ..  ..  ..   ...   ...  ...
# 386        16                Lecce  38   8  12  18  33  46 -13.0  36.0  ...
# 387        17               Verona  38   7  10  21  31  59 -28.0  31.0  ...
# 388        18               Spezia  38   6  13  19  31  62 -31.0  31.0  ...
# 389        19            Cremonese  38   5  12  21  36  69 -33.0  27.0  ...
# 390        20            Sampdoria  38   3  10  25  24  71 -47.0  19.0  ...
#
#      G+A-PK  xG.1  xAG.1  xG+xAG  npxG.1  npxG+xAG.1  Playoff_Rank   P  +/-  \
# 0      1.12  0.97   0.70    1.67    0.92        1.62           NaN NaN  NaN
# 1      1.65  1.10   0.76    1.86    0.98        1.74           NaN NaN  NaN
# 2      4.82  2.23   1.62    3.86    2.00        3.63           NaN NaN  NaN
# 3      3.76  1.95   1.50    3.45    1.78        3.28           NaN NaN  NaN
# 4      3.15  1.72   1.29    3.01    1.54        2.83           NaN NaN  NaN
# ..      ...   ...    ...     ...     ...         ...           ...  ..  ...
# 386    1.76  1.36   0.95    2.31    1.16        2.11           NaN NaN  NaN
# 387    1.13  1.09   0.77    1.86    1.01        1.78           NaN NaN  NaN
# 388    1.92  1.10   0.92    2.02    1.06        1.98           NaN NaN  NaN
# 389    2.26  1.24   0.99    2.23    1.20        2.19           NaN NaN  NaN
# 390    1.32  0.94   0.74    1.68    0.92        1.66           NaN NaN  NaN
#
#      PTS
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# ..   ...
# 386  NaN
# 387  NaN
# 388  NaN
# 389  NaN
# 390  NaN
#
# [391 rows x 49 columns]

# %%
# Create a unified 'Club' column by taking the first non-null value between 'Club' and 'Team'
all_league_data['Pts'] = all_league_data['Pts'].combine_first(all_league_data['PTS'])

# Now that we have a unified column, we can drop the 'Team' column
all_league_data.drop(columns=['PTS'], inplace=True)

# %%
all_league_data
# Out:
#      Reg_Rank                 Club  MP   W   D   L  GF  GA    GD   Pts  ...  \
# 0          15              Arminia  34   9   8  17  26  52 -26.0  35.0  ...
# 1          13             Augsburg  34  10   6  18  36  54 -18.0  36.0  ...
# 2           1               Bayern  34  24   6   4  99  44  55.0  78.0  ...
# 3           3             Dortmund  34  20   4  10  75  46  29.0  64.0  ...
# 4           5  Eintracht Frankfurt  34  16  12   6  69  53  16.0  60.0  ...
# ..        ...                  ...  ..  ..  ..  ..  ..  ..   ...   ...  ...
# 386        16                Lecce  38   8  12  18  33  46 -13.0  36.0  ...
# 387        17               Verona  38   7  10  21  31  59 -28.0  31.0  ...
# 388        18               Spezia  38   6  13  19  31  62 -31.0  31.0  ...
# 389        19            Cremonese  38   5  12  21  36  69 -33.0  27.0  ...
# 390        20            Sampdoria  38   3  10  25  24  71 -47.0  19.0  ...
#
#      G-PK.1  G+A-PK  xG.1  xAG.1  xG+xAG  npxG.1  npxG+xAG.1  Playoff_Rank  \
# 0      0.65    1.12  0.97   0.70    1.67    0.92        1.62           NaN
# 1      0.97    1.65  1.10   0.76    1.86    0.98        1.74           NaN
# 2      2.62    4.82  2.23   1.62    3.86    2.00        3.63           NaN
# 3      2.09    3.76  1.95   1.50    3.45    1.78        3.28           NaN
# 4      1.62    3.15  1.72   1.29    3.01    1.54        2.83           NaN
# ..      ...     ...   ...    ...     ...     ...         ...           ...
# 386    0.97    1.76  1.36   0.95    2.31    1.16        2.11           NaN
# 387    0.66    1.13  1.09   0.77    1.86    1.01        1.78           NaN
# 388    1.03    1.92  1.10   0.92    2.02    1.06        1.98           NaN
# 389    1.18    2.26  1.24   0.99    2.23    1.20        2.19           NaN
# 390    0.74    1.32  0.94   0.74    1.68    0.92        1.66           NaN
#
#       P  +/-
# 0   NaN  NaN
# 1   NaN  NaN
# 2   NaN  NaN
# 3   NaN  NaN
# 4   NaN  NaN
# ..   ..  ...
# 386 NaN  NaN
# 387 NaN  NaN
# 388 NaN  NaN
# 389 NaN  NaN
# 390 NaN  NaN
#
# [391 rows x 48 columns]

# %%
all_league_data.drop(columns=['P', '+/-'], inplace=True)

# %%
all_league_data
# Out:
#      Reg_Rank                 Club  MP   W   D   L  GF  GA    GD   Pts  ...  \
# 0          15              Arminia  34   9   8  17  26  52 -26.0  35.0  ...
# 1          13             Augsburg  34  10   6  18  36  54 -18.0  36.0  ...
# 2           1               Bayern  34  24   6   4  99  44  55.0  78.0  ...
# 3           3             Dortmund  34  20   4  10  75  46  29.0  64.0  ...
# 4           5  Eintracht Frankfurt  34  16  12   6  69  53  16.0  60.0  ...
# ..        ...                  ...  ..  ..  ..  ..  ..  ..   ...   ...  ...
# 386        16                Lecce  38   8  12  18  33  46 -13.0  36.0  ...
# 387        17               Verona  38   7  10  21  31  59 -28.0  31.0  ...
# 388        18               Spezia  38   6  13  19  31  62 -31.0  31.0  ...
# 389        19            Cremonese  38   5  12  21  36  69 -33.0  27.0  ...
# 390        20            Sampdoria  38   3  10  25  24  71 -47.0  19.0  ...
#
#      Ast.1  G+A.1  G-PK.1  G+A-PK  xG.1  xAG.1  xG+xAG  npxG.1  npxG+xAG.1  \
# 0     0.47   1.15    0.65    1.12  0.97   0.70    1.67    0.92        1.62
# 1     0.68   1.71    0.97    1.65  1.10   0.76    1.86    0.98        1.74
# 2     2.21   5.09    2.62    4.82  2.23   1.62    3.86    2.00        3.63
# 3     1.68   3.85    2.09    3.76  1.95   1.50    3.45    1.78        3.28
# 4     1.53   3.38    1.62    3.15  1.72   1.29    3.01    1.54        2.83
# ..     ...    ...     ...     ...   ...    ...     ...     ...         ...
# 386   0.79   2.00    0.97    1.76  1.36   0.95    2.31    1.16        2.11
# 387   0.47   1.24    0.66    1.13  1.09   0.77    1.86    1.01        1.78
# 388   0.89   1.97    1.03    1.92  1.10   0.92    2.02    1.06        1.98
# 389   1.08   2.29    1.18    2.26  1.24   0.99    2.23    1.20        2.19
# 390   0.58   1.34    0.74    1.32  0.94   0.74    1.68    0.92        1.66
#
#      Playoff_Rank
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ..            ...
# 386           NaN
# 387           NaN
# 388           NaN
# 389           NaN
# 390           NaN
#
# [391 rows x 46 columns]

# %%
# Create a unified 'Club' column by taking the first non-null value between 'Club' and 'Team'
all_league_data['GF'] = all_league_data['GF'].combine_first(all_league_data['Gls'])

# Now that we have a unified column, we can drop the 'Team' column
all_league_data.drop(columns=['Gls'], inplace=True)
all_league_data.drop(columns=['Playoff_Rank'], inplace=True)
all_league_data.drop(columns=['Pts'], inplace=True)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

# Assume all_league_data is your DataFrame

# Step 1: Separate target and features
y = all_league_data['W']  # The target variable is the number of wins
X = all_league_data.drop(columns=['W'])  # Drop the target from the features

# (Optional) If you have categorical variables, you may need to encode them:
# For example, if 'Club' is categorical:
# X = pd.get_dummies(X, columns=['Club'], drop_first=True)

# Step 2: Identify numeric features and subset
numeric_cols = X.select_dtypes(include='number').columns
X_numeric = X[numeric_cols]

# Step 3: Standard Scaling
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_numeric)

# Step 4: Create train-validation-test splits
# First split off the test set
X_train_val, X_test, y_train_val, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

# Then split the train_val into train and validation
X_train, X_val, y_train, y_val = train_test_split(
    X_train_val, y_train_val, test_size=0.25, random_state=42
)
# Now:
# - Training set: 60% of data
# - Validation set: 20% of data
# - Test set: 20% of data

# Step 5: Train a Random Forest model on the training set
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# Step 6: Evaluate on the validation set (for hyperparameter tuning)
y_val_pred = model.predict(X_val)
val_mse = mean_squared_error(y_val, y_val_pred)
val_r2 = r2_score(y_val, y_val_pred)
print("Validation MSE:", val_mse)
print("Validation R²:", val_r2)

# (Optional) If needed, perform hyperparameter tuning here
# e.g., try different n_estimators, max_depth, etc., and re-check on X_val, y_val

# After finalizing the model/hyperparameters,
# retrain the model on the combined (train+val) set for the final evaluation:
model_final = RandomForestRegressor(n_estimators=100, random_state=42)
model_final.fit(X_train_val, y_train_val)

# Evaluate on the test set
y_test_pred = model_final.predict(X_test)
test_mse = mean_squared_error(y_test, y_test_pred)
test_r2 = r2_score(y_test, y_test_pred)
print("Test MSE:", test_mse)
print("Test R²:", test_r2)
# Out:
# Validation MSE: 3.939312820512821
# Validation R²: 0.8656299522325133
# Test MSE: 4.738812658227848
# Test R²: 0.8871013521148267

# %%
importances = model.feature_importances_

# If you have a list of feature column names (e.g., after encoding/scaling)
# For instance, if you scaled only numeric columns:
feature_names = numeric_cols  # The columns you fed into the scaler and model

# Create a DataFrame for readability
feature_importance_df = pd.DataFrame({
    'feature': feature_names,
    'importance': importances
})

# Sort by importance
feature_importance_df = feature_importance_df.sort_values(by='importance', ascending=False)

print(feature_importance_df)
# Out:
#                               feature  importance
# 6                                  GD    0.297198
# 4                                  GF    0.249063
# 0                            Reg_Rank    0.168265
# 20                               G-PK    0.043664
# 8   Average Annual Payroll (Millions)    0.037304
# 10             Average Annual Payroll    0.029729
# 19                                G+A    0.024158
# 7     Total Annual Payroll (Millions)    0.016527
# 9                Total Annual Payroll    0.015892
# 2                                   D    0.011238
# 29                               PrgC    0.008152
# 22                              PKatt    0.007662
# 3                                   L    0.007243
# 23                               CrdY    0.006957
# 5                                  GA    0.006539
# 25                                 xG    0.006473
# 18                                Ast    0.005066
# 30                               PrgP    0.005032
# 12                                Age    0.004695
# 26                               npxG    0.004280
# 13                               Poss    0.004192
# 14                               MP.1    0.003212
# 21                                 PK    0.002940
# 15                             Starts    0.002917
# 17                                90s    0.002670
# 11                               # Pl    0.002520
# 24                               CrdR    0.002463
# 28                           npxG+xAG    0.002244
# 40                         npxG+xAG.1    0.002139
# 32                              Ast.1    0.002062
# 36                               xG.1    0.001942
# 34                             G-PK.1    0.001863
# 1                                  MP    0.001844
# 27                                xAG    0.001841
# 37                              xAG.1    0.001803
# 31                              Gls.1    0.001794
# 35                             G+A-PK    0.001664
# 39                             npxG.1    0.001553
# 16                                Min    0.001110
# 33                              G+A.1    0.001073
# 38                             xG+xAG    0.001014

# %%
import matplotlib.pyplot as plt

importances = model.feature_importances_
feature_importance_df = pd.DataFrame({'feature': numeric_cols, 'importance': importances})
feature_importance_df = feature_importance_df.sort_values(by='importance', ascending=False)

plt.figure(figsize=(10,6))
plt.barh(feature_importance_df['feature'], feature_importance_df['importance'])
plt.gca().invert_yaxis()  # highest importance at top
plt.title('Feature Importances')
plt.xlabel('Importance Score')
plt.show()

# %%
y_pred = model.predict(X_val)
residuals = y_val - y_pred

plt.figure(figsize=(8,6))
plt.scatter(y_val, residuals)
plt.hlines(y=0, xmin=min(y_val), xmax=max(y_val), color='red')
plt.title('Residuals vs. Actual Values')
plt.xlabel('Actual Values')
plt.ylabel('Residual (Actual - Predicted)')
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.scatter(y_val, y_pred, alpha=0.7)
plt.plot([y_val.min(), y_val.max()], [y_val.min(), y_val.max()], 'k--', lw=2)
plt.title('Predicted vs. Actual Wins')
plt.xlabel('Actual Wins')
plt.ylabel('Predicted Wins')
plt.show()

# %%
from sklearn.neural_network import MLPRegressor
nn_model = MLPRegressor(hidden_layer_sizes=(64, 64),  # two hidden layers with 64 neurons each
                        activation='relu',
                        solver='adam',
                        random_state=42,
                        max_iter=1000)

nn_model.fit(X_train, y_train)

# Evaluate on validation set
y_val_pred_nn = nn_model.predict(X_val)
val_mse_nn = mean_squared_error(y_val, y_val_pred_nn)
val_r2_nn = r2_score(y_val, y_val_pred_nn)
print("Neural Network Validation MSE:", val_mse_nn)
print("Neural Network Validation R²:", val_r2_nn)

# If this looks good, retrain on train+val and evaluate on test:
nn_model_final = MLPRegressor(hidden_layer_sizes=(64, 64),
                              activation='relu',
                              solver='adam',
                              random_state=42,
                              max_iter=1000)
nn_model_final.fit(X_train_val, y_train_val)

y_test_pred_nn = nn_model_final.predict(X_test)
test_mse_nn = mean_squared_error(y_test, y_test_pred_nn)
test_r2_nn = r2_score(y_test, y_test_pred_nn)
print("Neural Network Test MSE:", test_mse_nn)
print("Neural Network Test R²:", test_r2_nn)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 8
#       1 from sklearn.neural_network import MLPRegressor
#       2 nn_model = MLPRegressor(hidden_layer_sizes=(64, 64),  # two hidden layers with 64 neurons each
#       3                         activation='relu',
#       4                         solver='adam',
#       5                         random_state=42,
#       6                         max_iter=1000)
# ----> 8 nn_model.fit(X_train, y_train)
#      10 # Evaluate on validation set
#      11 y_val_pred_nn = nn_model.predict(X_val)
#
# File /opt/homebrew/lib/python3.11/site-packages/sklearn/base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:751, in BaseMultilayerPerceptron.fit(self, X, y)
#     733 @_fit_context(prefer_skip_nested_validation=True)
#     734 def fit(self, X, y):
#     735     """Fit the model to data matrix X and target(s) y.
#     736
#     737     Parameters
#    (...)
#     749         Returns a trained MLP model.
#     750     """
# --> 751     return self._fit(X, y, incremental=False)
#
# File /opt/homebrew/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:441, in BaseMultilayerPerceptron._fit(self, X, y, incremental)
#     434     raise ValueError(
#     435         "hidden_layer_sizes must be > 0, got %s." % hidden_layer_sizes
#     436     )
#     437 first_pass = not hasattr(self, "coefs_") or (
#     438     not self.warm_start and not incremental
#     439 )
# --> 441 X, y = self._validate_input(X, y, incremental, reset=first_pass)
#     443 n_samples, n_features = X.shape
#     445 # Ensure y is 2D
#
# File /opt/homebrew/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:1621, in MLPRegressor._validate_input(self, X, y, incremental, reset)
#    1620 def _validate_input(self, X, y, incremental, reset):
# -> 1621     X, y = self._validate_data(
#    1622         X,
#    1623         y,
#    1624         accept_sparse=["csr", "csc"],
#    1625         multi_output=True,
#    1626         y_numeric=True,
#    1627         dtype=(np.float64, np.float32),
#    1628         reset=reset,
#    1629     )
#    1630     if y.ndim == 2 and y.shape[1] == 1:
#    1631         y = column_or_1d(y, warn=True)
#
# File /opt/homebrew/lib/python3.11/site-packages/sklearn/base.py:650, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     648         y = check_array(y, input_name="y", **check_y_params)
#     649     else:
# --> 650         X, y = check_X_y(X, y, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
#
# File /opt/homebrew/lib/python3.11/site-packages/sklearn/utils/validation.py:1301, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1296         estimator_name = _check_estimator_name(estimator)
#    1297     raise ValueError(
#    1298         f"{estimator_name} requires y to be passed, but the target y is None"
#    1299     )
# -> 1301 X = check_array(
#    1302     X,
#    1303     accept_sparse=accept_sparse,
#    1304     accept_large_sparse=accept_large_sparse,
#    1305     dtype=dtype,
#    1306     order=order,
#    1307     copy=copy,
#    1308     force_writeable=force_writeable,
#    1309     force_all_finite=force_all_finite,
#    1310     ensure_2d=ensure_2d,
#    1311     allow_nd=allow_nd,
#    1312     ensure_min_samples=ensure_min_samples,
#    1313     ensure_min_features=ensure_min_features,
#    1314     estimator=estimator,
#    1315     input_name="X",
#    1316 )
#    1318 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1320 check_consistent_length(X, y)
#
# File /opt/homebrew/lib/python3.11/site-packages/sklearn/utils/validation.py:1064, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1058     raise ValueError(
#    1059         "Found array with dim %d. %s expected <= 2."
#    1060         % (array.ndim, estimator_name)
#    1061     )
#    1063 if force_all_finite:
# -> 1064     _assert_all_finite(
#    1065         array,
#    1066         input_name=input_name,
#    1067         estimator_name=estimator_name,
#    1068         allow_nan=force_all_finite == "allow-nan",
#    1069     )
#    1071 if copy:
#    1072     if _is_numpy_namespace(xp):
#    1073         # only make a copy if `array` and `array_orig` may share memory`
#
# File /opt/homebrew/lib/python3.11/site-packages/sklearn/utils/validation.py:123, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     120 if first_pass_isfinite:
#     121     return
# --> 123 _assert_all_finite_element_wise(
#     124     X,
#     125     xp=xp,
#     126     allow_nan=allow_nan,
#     127     msg_dtype=msg_dtype,
#     128     estimator_name=estimator_name,
#     129     input_name=input_name,
#     130 )
#
# File /opt/homebrew/lib/python3.11/site-packages/sklearn/utils/validation.py:172, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     155 if estimator_name and input_name == "X" and has_nan_error:
#     156     # Improve the error message on how to handle missing values in
#     157     # scikit-learn.
#     158     msg_err += (
#     159         f"\n{estimator_name} does not accept missing values"
#     160         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     170         "#estimators-that-handle-nan-values"
#     171     )
# --> 172 raise ValueError(msg_err)
#
# ValueError: Input X contains NaN.
# MLPRegressor does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %%
nan_rows = all_league_data[all_league_data.isna().any(axis=1)]
nan_rows
# Out:
#      Reg_Rank        Club  MP   W   D   L   GF  GA    GD  \
# 313        16        ABHA  34   9   5  20   38  87   NaN
# 314         3     AL AHLI  34  19   8   7   67  35   NaN
# 315        15  AL AKHDOUD  34   9   6  19   33  52   NaN
# 316         6  AL ETTIFAQ  34  12  12  10   43  34   NaN
# 317         7    AL FATEH  34  12   9  13   57  55   NaN
# 318         9    AL FAYHA  34  11  11  12   44  52   NaN
# 319        18    AL HAZEM  34   4  12  18   34  76   NaN
# 320         1    AL HILAL  34  31   3   0  101  23   NaN
# 321         5  AL ITTIHAD  34  16   6  12   63  54   NaN
# 322        11  AL KHALEEJ  34   9  10  15   36  47   NaN
# 323         2    AL NASSR  34  26   6   4  100  42   NaN
# 324        12     AL RAED  34   9  10  15   41  49   NaN
# 325         8   AL SHABAB  34  12   8  14   45  42   NaN
# 326         4  AL TAAWOUN  34  16  11   7   51  35   NaN
# 327        17      AL TAE  34   8   7  19   34  64   NaN
# 328        13    AL WEHDA  34  10   6  18   45  60   NaN
# 329        10       DHAMK  34  10  11  13   44  45   NaN
# 330        14   RIYADH SC  34   8  11  15   33  57   NaN
# 350        20       Parma  38   3  11  24   39  83 -44.0
#
#      Total Annual Payroll (Millions)  ...  Gls.1  Ast.1  G+A.1  G-PK.1  \
# 313                              NaN  ...   1.00   0.62   1.62    0.88
# 314                          149.080  ...   1.91   1.47   3.38    1.76
# 315                              NaN  ...   0.94   0.59   1.53    0.82
# 316                           66.650  ...   1.21   0.82   2.03    1.15
# 317                              NaN  ...   1.68   1.24   2.91    1.56
# 318                              NaN  ...   1.29   1.03   2.32    1.15
# 319                              NaN  ...   1.00   0.56   1.56    0.85
# 320                          256.250  ...   2.91   1.82   4.74    2.44
# 321                          178.350  ...   1.79   1.29   3.09    1.59
# 322                              NaN  ...   0.97   0.56   1.53    0.76
# 323                          346.060  ...   2.94   1.94   4.88    2.62
# 324                              NaN  ...   1.21   0.85   2.06    1.09
# 325                           66.790  ...   1.21   0.85   2.06    1.12
# 326                              NaN  ...   1.47   1.06   2.53    1.38
# 327                              NaN  ...   0.91   0.59   1.50    0.79
# 328                              NaN  ...   1.29   0.79   2.09    1.09
# 329                              NaN  ...   1.21   0.85   2.06    1.06
# 330                              NaN  ...   0.91   0.56   1.47    0.79
# 350                           41.777  ...   1.05   0.79   1.84     NaN
#
#      G+A-PK  xG.1  xAG.1  xG+xAG  npxG.1  npxG+xAG.1
# 313    1.50   NaN    NaN     NaN     NaN         NaN
# 314    3.24   NaN    NaN     NaN     NaN         NaN
# 315    1.41   NaN    NaN     NaN     NaN         NaN
# 316    1.97   NaN    NaN     NaN     NaN         NaN
# 317    2.79   NaN    NaN     NaN     NaN         NaN
# 318    2.18   NaN    NaN     NaN     NaN         NaN
# 319    1.41   NaN    NaN     NaN     NaN         NaN
# 320    4.26   NaN    NaN     NaN     NaN         NaN
# 321    2.88   NaN    NaN     NaN     NaN         NaN
# 322    1.32   NaN    NaN     NaN     NaN         NaN
# 323    4.56   NaN    NaN     NaN     NaN         NaN
# 324    1.94   NaN    NaN     NaN     NaN         NaN
# 325    1.97   NaN    NaN     NaN     NaN         NaN
# 326    2.44   NaN    NaN     NaN     NaN         NaN
# 327    1.38   NaN    NaN     NaN     NaN         NaN
# 328    1.88   NaN    NaN     NaN     NaN         NaN
# 329    1.91   NaN    NaN     NaN     NaN         NaN
# 330    1.35   NaN    NaN     NaN     NaN         NaN
# 350     NaN   NaN    NaN     NaN     NaN         NaN
#
# [19 rows x 43 columns]
